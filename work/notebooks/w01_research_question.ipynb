# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roudysabry/ML-Project---Roudy/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
#
# I chose **Lane 2: Refresh / Content Opportunity Scoring** because it focuses on identifying which content pages should be reviewed first. This project helps prioritize limited review time by ranking pages based on observable data instead of relying on manual decisions. I chose this lane because it has a clear business value and is supported by the starter dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### Research Question
#
# Which content pages should be reviewed first for refresh or improvement?
#
# ### Decision
#
# The project helps decide which pages should be prioritized for review.
#
# ### Action
#
# A content reviewer or SEO specialist reviews the highest-ranked pages and decides whether to refresh, improve, or monitor them.
#
# ### Cost of a Wrong Recommendation
#
# If an important page is missed, valuable traffic may continue to decline. If a low-priority page is selected instead, time and resources are wasted.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# The starter dataset will be explored to understand its size and some basic characteristics. These numbers will help justify why this lane is worth investigating over the next seven weeks.

# %% [markdown]
# The starter dataset contains 30,000 content pages and 44 features. Most pages (16,262) show a downward trend, suggesting many pages may need review or improvement. The average number of impressions is about 5,200, indicating that these pages receive measurable traffic and that prioritizing which pages to refresh could have practical value.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("/content/content_refresh_anonymized.csv")

print("Rows, Columns:", df.shape)
print("\nTrend Direction:")
print(df["trend_direction"].value_counts())

print("\nAverage Impressions:")
print(df["impressions_90d"].mean())
# Out:
# Rows, Columns: (30000, 44)
#
# Trend Direction:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average Impressions:
# 5200.3663

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project provides decision support by identifying pages that may be good candidates for review. The results should be treated as recommendations rather than proof that refreshing a page will improve its performance. The model cannot guarantee future traffic or predict how search engines will rank pages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ✅] Every section above is filled — markdown thinking AND the code that backs it
# - [ ✅] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ✅] No client names, URLs, or private queries anywhere
# - [ ✅] My claims use careful words: observed, measured, directional, decision-support
# - [ ✅] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
